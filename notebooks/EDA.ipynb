# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r'C:\Users\Arpit Babu\Downloads\student-performance-prediction\Data\student_performance.csv')

print(df.head())
print(df.info())
print(df.describe())
# Out:
#    StudyHours  Attendance  PreviousScore Result
# 0           2          60             45   Fail
# 1           3          70             50   Fail
# 2           5          80             65   Pass
# 3           6          85             70   Pass
# 4           1          50             40   Fail
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StudyHours     30 non-null     int64
#  1   Attendance     30 non-null     int64
#  2   PreviousScore  30 non-null     int64
#  3   Result         30 non-null     str
# dtypes: int64(3), str(1)
# memory usage: 1.2 KB
# None
#        StudyHours  Attendance  PreviousScore
# count   30.000000   30.000000      30.000000
# mean     4.333333   75.300000      61.733333
# std      2.218004   13.646144      15.222337
# min      1.000000   50.000000      38.000000
# 25%      2.250000   65.250000      48.500000
# 50%      4.000000   75.500000      60.500000
# 75%      6.000000   86.500000      73.500000
# max      8.000000   98.000000      90.000000

# %%
print(df['Result'].value_counts())
# Out:
# Result
# Pass    18
# Fail    12
# Name: count, dtype: int64

# %%
sns.pairplot(df, hue='Result')
plt.show()

# %%
print(df.isnull().sum())
# Out:
# StudyHours       0
# Attendance       0
# PreviousScore    0
# Result           0
# dtype: int64
